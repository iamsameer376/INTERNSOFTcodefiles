# %%
import os
import time
import subprocess
import json

# %%
import wolframalpha
import requests
import webbrowser
import wikipedia
import datetime

# %%
import speech_recognition as sr
import pyttsx3

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
print('LOADING YOUR AI PERSONAL ASSISTANT JARVIS')
# Out:
# LOADING YOUR AI PERSONAL ASSISTANT JARVIS

# %%
engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
engine.setProperty('voice','voices[0].id')

# %%
def speak(text):
    engine.say(text)
    engine.runAndWait()

# %%
def wishMe():
    hour = datetime.datetime.now().hour
    if hour >= 0 and hour < 12:
        speak('hello, good morning Ms. Anya')
        print('hello, good morning Ms. Anya')
    elif hour >= 12 and hour <= 18:
        speak('hello, good afternoon Ms. Anya')
        print('hello, good afternoon Ms. Anya')
    elif hour >= 17 and hour <= 20:
        speak('hello, good evening Ms. Anya')
        print('hello, good evening Ms. Anya')
    else:
        speak('Its already night time better go to sleep')
        print('Its already night time better go to sleep')

# %%
def takeCommand():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print('I AM LISTENING')
        audio = r.listen(source)

        try:
            statement = r.recognize_google(audio, language='en-in')
            print(f"user said:{statement}\n")
            
        except Exception as e:
            speak('Pardon me, can u repeat that again')
            return 'none'
        return statement.lower()

# %%
if __name__ == '__main__':
    app_id = 'XWL824-WEGETVGX6R'
    client = wolframalpha.Client(app_id)

    while True:
        speak('How can I help you?')
        statement = takeCommand()

        if statement == 'none':
            continue

        if 'good bye' in statement or 'ok bye' in statement or 'see you later' in statement:
            speak('Your personal AI assistant JARVIS is shutting down. Goodbye!')
            print('Your personal AI assistant JARVIS is shutting down. Goodbye!')
            break

        elif 'wikipedia' in statement:
            speak('Searching Wikipedia...')
            statement = statement.replace('wikipedia', '')
            results = wikipedia.summary(statement, sentences=3)
            speak('According to Wikipedia...')
            print(results)
            speak(results)

        elif 'open youtube' in statement:
            webbrowser.open_new_tab('https://www.youtube.com')
            speak('YouTube is open for you.')
            time.sleep(5)

        elif 'open google' in statement:
            webbrowser.open_new_tab('https://www.google.com')
            speak('Google search is open for you.')
            time.sleep(5)

        elif 'open email' in statement:
            webbrowser.open_new_tab('https://gmail.com')
            speak('Your Gmail is open for you.')
            time.sleep(5)

        elif 'time' in statement:
            strTime = datetime.datetime.now().strftime('%H:%M:%S')
            speak(f'The time is {strTime}')

        elif 'who are you' in statement or 'what can you do' in statement:
            speak('I am JARVIS version 1.0, your personal assistant. I can open YouTube, Google Chrome, Gmail, and Stack Overflow, '
                  'tell the time, search Wikipedia, predict the weather, fetch news headlines from Times of India, and answer computational and geographical questions.')

        elif 'who made you' in statement or 'who created you' in statement or 'who discovered you' in statement:
            speak('I was built by Iron Man.')
            print('I was built by Iron Man.')

        elif 'open stack overflow' in statement:
            webbrowser.open_new_tab('https://stackoverflow.com')
            time.sleep(5)

        elif 'news' in statement:
            webbrowser.open_new_tab('https://timesofindia.indiatimes.com/home/headlines')
            speak('Here are some headlines for you from Times of India.')
            time.sleep(7)

        elif 'search' in statement:
            statement = statement.replace('search', '')
            webbrowser.open_new_tab(f"https://www.google.com/search?q={statement}")
            time.sleep(5)

        # Separate elif block for weather-related queries
        elif 'weather' in statement:
            speak("Which city's weather do you want to know?")
            city = takeCommand()

            if city == 'none':
                speak("I didn't catch that. Please try again.")
                continue

            question = f"weather in {city}"
            res = client.query(question)

            try:
                answer = next(res.results).text
                speak(f"The weather in {city} is {answer}")
                print(f"The weather in {city} is {answer}")
            except StopIteration:
                speak("I couldn't find the weather information.")
                print("No weather data found.")

        elif 'ask' in statement:
            speak('I can answer computational and geographical questions. What do you want to ask?')
            question = takeCommand()

            res = client.query(question)
            try:
                answer = next(res.results).text
                speak(answer)
                print(answer)
            except:
                Stop
# Out:
# I AM LISTENING
# user said:what is the weather
#
# I AM LISTENING
# I AM LISTENING
# user said:what's the weather
#
# I AM LISTENING
# user said:Bengaluru
#
# The weather in bengaluru is temperature | 34 °C (heat index: 38 °C)
# conditions | few clouds
# relative humidity | 47% (dew point: 21 °C)
# wind speed | 3 m/s
# (49 minutes ago)
# (using weather station VOTR: 273 km SSE and 830 meters below Bengaluru)
# I AM LISTENING
# user said:can I ask you something
#
# I AM LISTENING
# user said:what is the distance between Earth and Sun
#
# 0.9991 au (astronomical units)
# I AM LISTENING
# user said:what is Tan 45°
#
# I AM LISTENING
# user said:can I ask you something
#
# I AM LISTENING
# user said:45
#
# 45 is an odd number.
# I AM LISTENING
# user said:can I ask you something
#
# I AM LISTENING
# user said:tan 45 degrees
#
# 1
# I AM LISTENING
# user said:open Google for me
#
# I AM LISTENING
# user said:can you search in Google
#
# I AM LISTENING
# user said:what is the time
#
# I AM LISTENING
# user said:YouTube for me
#
# I AM LISTENING
# user said:new open YouTube
#
# I AM LISTENING
# user said:who is Elon Musk search
#
# I AM LISTENING
# I AM LISTENING
# user said:tell me something about Elon Musk from Wikipedia
#
# Elon Musk is the owner of multiple companies, the wealthiest individual in the world, and a US government employee. Having rejected the conservative label, Musk has described himself as a political moderate; his views have become more right-wing over time, and have been characterized as libertarian and far-right. As the owner of Twitter, he has  suppressed critics, and after his involvement in European politics, his views have received criticism from some world leaders.
# I AM LISTENING
# user said:what can you do
#
# I AM LISTENING
# I AM LISTENING
# user said:ok bye
#
# Your personal AI assistant JARVIS is shutting down. Goodbye!
